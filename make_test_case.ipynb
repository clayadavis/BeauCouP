# %%
import numpy as np
import pandas as pd

# %%
x = np.hstack((np.random.poisson(10.0, 100),
               np.random.poisson(20.0, 100),
               np.random.poisson( 8.0, 100),
             ))

# %%
pd.Series(x).plot()

# %%
open('test_case.txt', 'w').write('\n'.join(x.astype(str)))

# %%
# !head test_case.txt
# Out:
# 8
# 9
# 12
# 16
# 12
# 10
# 12
# 11
# 7
# 7
